# %%
file_path = 'sample1.txt'
file = open(file_path, 'r')

# %% [markdown]
# **Reading from a Text File**

# %%
content = file.read()

# %% [markdown]
# **Writting to a text file**

# %%
file = open(file_path, "w")
text="Hi i am anirban"
file.write(text)
# Out:
# 15

# %% [markdown]
# **Closing a text file**

# %%
file.close()

# %%
file_path = 'sample1.txt'
file = open(file_path, 'r')

# %% [markdown]
# **Repeating of Lines**

# %%
with open(file_path, 'r') as file:
    for line in file:
        print(line)
# Out:
# Hi i am anirban

# %%
lines = ["Line 1\n", "Line 2\n", "Line 3\n"]

with open("sample_file.txt", "w") as file:
    file.writelines(lines)

# %% [markdown]
# **Seeking a specific position**

# %%
file.seek(0)  # Moves the cursor to the beginning of the file
# Out:
# 0

# %% [markdown]
# **Checking a file existance**

# %%
import os

if os.path.exists(file_path):
    file = open(file_path, 'r')

# %% [markdown]
# **Reading writing extracting and updatiing text from the file**

# %%
def read__file(file_path):
    with open(file_path, 'r') as file:
        text = file.read()
    return text


def write__file(file_path, text):
    with open(file_path, 'w') as file:
        file.write(text)


def extract_text__file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        extracted_text = ' '.join(lines)
    return extracted_text




text = read_text_file(file_path)
print("Read text from the file")
print(text)


new_text = "My age is 22"
write_text_file(file_path, new_text)
print("New text written in the file")


upd_text = read_text_file(file_path)
print("Reading the text from the file after wriing")
print(upd_text)


extr = extract_text_from_file(file_path)
print("Extract the text from the file")
print(extr)
# Out:
# Read text from the file
# My age is 22
# New text written in the file
# Reading the text from the file after wriing
# My age is 22
# Extract the text from the file
# My age is 22
